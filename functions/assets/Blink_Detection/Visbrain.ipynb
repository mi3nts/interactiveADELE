# %%
import vispy

vispy.test()
# Out:
# ----------------------------------------------------------------------
# Skipping backend pyqt4, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "PyQt4":
#     No module named 'PyQt4'
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# msg:
# _VISPY_TESTING_APP=pyqt5 C:\Users\Ash\anaconda3\python.exe -m pytest -m vispy_app_test -ra C:\Users\Ash\anaconda3\lib\site-packages\vispy
# Failed: unit failure (1)
#
# ----------------------------------------------------------------------
# Skipping backend pyqt6, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "PyQt6":
#     No module named 'PyQt6'
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend pyside, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "PySide":
#     No module named 'PySide'
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend pyside2, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "PySide2":
#     No module named 'PySide2'
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend pyside6, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "PySide6":
#     No module named 'PySide6'
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend pyglet, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "Pyglet":
#     No module named 'pyglet'
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend glfw, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "Glfw":
#     Could not import glwf, you may need to `pip install glfw` first.
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend sdl2, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "SDL2":
#     No module named 'sdl2'
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend wx, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "wx":
#     No module named 'wx'
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend egl, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "EGL":
#     EGL library not found
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend osmesa, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "osmesa":
#     OSMesa library not found
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend jupyter_rfb, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "jupyter_rfb":
#     The jupyter_rfb backend relies on a the jupyter_rfb library: ``pip install jupyter_rfb``
#
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Skipping backend _test, not installed or working properly:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\_default_app.py", line 47, in use_app
#         default_app = Application(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 47, in __init__
#         self._use(backend_name)
#       File "C:\Users\Ash\anaconda3\lib\site-packages\vispy\app\application.py", line 240, in _use
#         raise RuntimeError(msg)
#     RuntimeError: Could not import backend "_test":
#     test backend should be skipped
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# msg:
# _VISPY_TESTING_APP=nobackend C:\Users\Ash\anaconda3\python.exe -m pytest -m not vispy_app_test -ra C:\Users\Ash\anaconda3\lib\site-packages\vispy
# Failed: unit failure (1)
# Skipping example test: Cannot test examples unless in vispy git directory
# Skipping line endings check on Windows
# Passed
#
# Running flake8...
# vispy\app\canvas.py:401:80: E501 line too long (80 > 79 characters)
# vispy\app\canvas.py:522:80: E501 line too long (85 > 79 characters)
# vispy\app\canvas.py:533:80: E501 line too long (85 > 79 characters)
# vispy\app\canvas.py:567:80: E501 line too long (80 > 79 characters)
# vispy\app\_detect_eventloop.py:48:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\app\backends\_glfw.py:30:80: E501 line too long (80 > 79 characters)
# vispy\app\backends\_jupyter_rfb.py:13:80: E501 line too long (101 > 79 characters)
# vispy\app\backends\_jupyter_rfb.py:57:80: E501 line too long (88 > 79 characters)
# vispy\app\backends\_jupyter_rfb.py:80:80: E501 line too long (84 > 79 characters)
# vispy\app\backends\_jupyter_rfb.py:270:80: E501 line too long (91 > 79 characters)
# vispy\app\backends\_offscreen_util.py:47:80: E501 line too long (84 > 79 characters)
# vispy\app\backends\_offscreen_util.py:62:80: E501 line too long (80 > 79 characters)
# vispy\app\backends\_qt.py:67:80: E501 line too long (106 > 79 characters)
# vispy\app\backends\_qt.py:100:73: W291 trailing whitespace
# vispy\app\backends\_qt.py:212:80: E501 line too long (92 > 79 characters)
# vispy\app\backends\_qt.py:244:80: E501 line too long (86 > 79 characters)
# vispy\app\backends\_qt.py:286:80: E501 line too long (89 > 79 characters)
# vispy\app\backends\_qt.py:310:80: E501 line too long (91 > 79 characters)
# vispy\app\backends\_qt.py:315:80: E501 line too long (98 > 79 characters)
# vispy\app\backends\_qt.py:408:80: E501 line too long (83 > 79 characters)
# vispy\app\backends\_qt.py:419:80: E501 line too long (81 > 79 characters)
# vispy\app\backends\_qt.py:428:80: E501 line too long (94 > 79 characters)
# vispy\app\backends\_qt.py:429:80: E501 line too long (93 > 79 characters)
# vispy\app\backends\_qt.py:430:80: E501 line too long (91 > 79 characters)
# vispy\app\backends\_qt.py:577:80: E501 line too long (103 > 79 characters)
# vispy\app\backends\_qt.py:622:80: E501 line too long (86 > 79 characters)
# vispy\app\backends\_qt.py:673:80: E501 line too long (82 > 79 characters)
# vispy\app\backends\_qt.py:679:80: E501 line too long (84 > 79 characters)
# vispy\app\backends\_qt.py:803:80: E501 line too long (82 > 79 characters)
# vispy\app\backends\_qt.py:832:80: E501 line too long (88 > 79 characters)
# vispy\app\backends\_qt.py:884:80: E501 line too long (107 > 79 characters)
# vispy\app\backends\_tk.py:32:80: E501 line too long (90 > 79 characters)
# vispy\app\backends\_tk.py:43:80: E501 line too long (110 > 79 characters)
# vispy\app\backends\_tk.py:275:80: E501 line too long (88 > 79 characters)
# vispy\app\backends\_tk.py:385:80: E501 line too long (80 > 79 characters)
# vispy\app\backends\_tk.py:386:80: E501 line too long (82 > 79 characters)
# vispy\app\backends\_tk.py:400:80: E501 line too long (80 > 79 characters)
# vispy\app\backends\_tk.py:404:80: E501 line too long (82 > 79 characters)
# vispy\app\backends\_tk.py:425:80: E501 line too long (82 > 79 characters)
# vispy\app\backends\_tk.py:427:80: E501 line too long (81 > 79 characters)
# vispy\app\backends\_tk.py:430:80: E501 line too long (80 > 79 characters)
# vispy\app\backends\_tk.py:510:80: E501 line too long (82 > 79 characters)
# vispy\app\backends\_tk.py:597:80: E501 line too long (102 > 79 characters)
# vispy\app\backends\_tk.py:619:80: E501 line too long (102 > 79 characters)
# vispy\app\backends\_tk.py:635:80: E501 line too long (102 > 79 characters)
# vispy\app\backends\_tk.py:641:80: E501 line too long (86 > 79 characters)
# vispy\app\backends\_tk.py:661:80: E501 line too long (86 > 79 characters)
# vispy\app\backends\_tk.py:683:80: E501 line too long (85 > 79 characters)
# vispy\app\backends\_tk.py:760:80: E501 line too long (84 > 79 characters)
# vispy\app\backends\tests\test_offscreen_util.py:1:80: E501 line too long (82 > 79 characters)
# vispy\app\backends\tests\test_rfb.py:21:80: E501 line too long (83 > 79 characters)
# vispy\app\backends\tests\test_rfb.py:48:80: E501 line too long (104 > 79 characters)
# vispy\app\backends\tests\test_rfb.py:59:80: E501 line too long (104 > 79 characters)
# vispy\app\backends\tests\test_rfb.py:72:80: E501 line too long (111 > 79 characters)
# vispy\app\tests\test_app.py:15:80: E501 line too long (82 > 79 characters)
# vispy\app\tests\test_app.py:122:48: W291 trailing whitespace
# vispy\app\tests\test_app.py:123:31: W291 trailing whitespace
# vispy\app\tests\test_app.py:143:80: E501 line too long (83 > 79 characters)
# vispy\app\tests\test_app.py:384:80: E501 line too long (102 > 79 characters)
# vispy\app\tests\test_backends.py:44:80: E501 line too long (89 > 79 characters)
# vispy\app\tests\test_context.py:42:80: E501 line too long (83 > 79 characters)
# vispy\app\tests\test_context.py:44:80: E501 line too long (83 > 79 characters)
# vispy\app\tests\test_context.py:45:80: E501 line too long (81 > 79 characters)
# vispy\app\tests\test_context.py:72:80: E501 line too long (92 > 79 characters)
# vispy\app\tests\test_context.py:73:80: E501 line too long (83 > 79 characters)
# vispy\app\tests\test_context.py:77:80: E501 line too long (85 > 79 characters)
# vispy\app\tests\test_context.py:90:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\app\tests\test_simultaneous.py:11:80: E501 line too long (89 > 79 characters)
# vispy\app\tests\test_simultaneous.py:46:80: E501 line too long (101 > 79 characters)
# vispy\color\colormap.py:285:80: E501 line too long (84 > 79 characters)
# vispy\color\colormap.py:434:80: E501 line too long (84 > 79 characters)
# vispy\color\colormap.py:438:80: E501 line too long (81 > 79 characters)
# vispy\color\colormap.py:648:80: E501 line too long (83 > 79 characters)
# vispy\color\colormap.py:742:80: E501 line too long (82 > 79 characters)
# vispy\color\colormap.py:1125:80: E501 line too long (80 > 79 characters)
# vispy\color\colormap.py:1133:80: E501 line too long (87 > 79 characters)
# vispy\color\colormap.py:1136:80: E501 line too long (93 > 79 characters)
# vispy\ext\cocoapy.py:22:80: E501 line too long (96 > 79 characters)
# vispy\ext\cocoapy.py:60:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\ext\cocoapy.py:87:1: E305 expected 2 blank lines after class or function definition, found 0
# vispy\ext\cocoapy.py:92:1: E305 expected 2 blank lines after class or function definition, found 0
# vispy\ext\cocoapy.py:97:1: E305 expected 2 blank lines after class or function definition, found 0
# vispy\ext\cocoapy.py:434:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\ext\cocoapy.py:1081:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\ext\cocoapy.py:1100:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\ext\cocoapy.py:1116:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\ext\cubehelix.py:36:10: E128 continuation line under-indented for visual indent
# vispy\ext\cubehelix.py:37:10: E128 continuation line under-indented for visual indent
# vispy\ext\egl.py:321:80: E501 line too long (88 > 79 characters)
# vispy\ext\egl.py:329:80: E501 line too long (81 > 79 characters)
# vispy\ext\egl.py:340:80: E501 line too long (84 > 79 characters)
# vispy\ext\fontconfig.py:59:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\ext\gdi32plus.py:183:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\ext\gdi32plus.py:206:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\ext\osmesa.py:82:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\geometry\isocurve.py:24:63: W291 trailing whitespace
# vispy\geometry\isocurve.py:25:58: W291 trailing whitespace
# vispy\geometry\isocurve.py:28:63: W291 trailing whitespace
# vispy\geometry\isocurve.py:29:18: W291 trailing whitespace
# vispy\geometry\isocurve.py:30:8: W291 trailing whitespace
# vispy\geometry\isocurve.py:90:66: W291 trailing whitespace
# vispy\geometry\isocurve.py:92:80: E501 line too long (80 > 79 characters)
# vispy\geometry\isocurve.py:97:47: W291 trailing whitespace
# vispy\geometry\isocurve.py:100:48: W291 trailing whitespace
# vispy\geometry\isocurve.py:105:55: W291 trailing whitespace
# vispy\geometry\isocurve.py:112:68: W291 trailing whitespace
# vispy\geometry\isocurve.py:113:68: W291 trailing whitespace
# vispy\geometry\isocurve.py:115:77: W291 trailing whitespace
# vispy\geometry\isocurve.py:165:30: W291 trailing whitespace
# vispy\geometry\isosurface.py:9:51: W291 trailing whitespace
# vispy\geometry\isosurface.py:15:67: W291 trailing whitespace
# vispy\geometry\isosurface.py:16:36: W291 trailing whitespace
# vispy\geometry\isosurface.py:19:6: W291 trailing whitespace
# vispy\geometry\isosurface.py:20:73: W291 trailing whitespace
# vispy\geometry\isosurface.py:25:37: W291 trailing whitespace
# vispy\geometry\isosurface.py:31:79: W291 trailing whitespace
# vispy\geometry\isosurface.py:32:74: W291 trailing whitespace
# vispy\geometry\isosurface.py:33:80: W291 trailing whitespace
# vispy\geometry\isosurface.py:52:49: W291 trailing whitespace
# vispy\geometry\isosurface.py:53:67: W291 trailing whitespace
# vispy\geometry\isosurface.py:57:78: W291 trailing whitespace
# vispy\geometry\isosurface.py:65:33: W291 trailing whitespace
# vispy\geometry\isosurface.py:66:33: W291 trailing whitespace
# vispy\geometry\isosurface.py:67:33: W291 trailing whitespace
# vispy\geometry\isosurface.py:73:55: W291 trailing whitespace
# vispy\geometry\isosurface.py:79:55: W291 trailing whitespace
# vispy\geometry\isosurface.py:83:57: W291 trailing whitespace
# vispy\geometry\isosurface.py:91:69: W291 trailing whitespace
# vispy\geometry\isosurface.py:92:38: W291 trailing whitespace
# vispy\geometry\isosurface.py:94:79: W291 trailing whitespace
# vispy\geometry\isosurface.py:95:76: W291 trailing whitespace
# vispy\geometry\isosurface.py:115:42: W291 trailing whitespace
# vispy\geometry\isosurface.py:149:80: E501 line too long (100 > 79 characters)
# vispy\geometry\isosurface.py:150:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:150:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:151:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:151:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:152:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:152:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:153:80: E501 line too long (102 > 79 characters)
# vispy\geometry\isosurface.py:153:103: W291 trailing whitespace
# vispy\geometry\isosurface.py:154:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:154:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:155:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:155:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:156:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:156:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:157:80: E501 line too long (102 > 79 characters)
# vispy\geometry\isosurface.py:157:103: W291 trailing whitespace
# vispy\geometry\isosurface.py:158:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:158:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:159:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:159:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:160:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:160:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:161:80: E501 line too long (102 > 79 characters)
# vispy\geometry\isosurface.py:161:103: W291 trailing whitespace
# vispy\geometry\isosurface.py:162:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:162:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:163:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:163:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:164:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:164:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:165:80: E501 line too long (102 > 79 characters)
# vispy\geometry\isosurface.py:165:103: W291 trailing whitespace
# vispy\geometry\isosurface.py:166:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:166:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:167:80: E501 line too long (101 > 79 characters)
# vispy\geometry\isosurface.py:167:102: W291 trailing whitespace
# vispy\geometry\isosurface.py:168:80: E501 line too long (90 > 79 characters)
# vispy\geometry\isosurface.py:435:26: W291 trailing whitespace
# vispy\geometry\isosurface.py:448:79: W291 trailing whitespace
# vispy\geometry\isosurface.py:450:28: W291 trailing whitespace
# vispy\geometry\isosurface.py:462:67: W291 trailing whitespace
# vispy\geometry\meshdata.py:571:80: E501 line too long (83 > 79 characters)
# vispy\geometry\torusknot.py:74:80: E501 line too long (81 > 79 characters)
# vispy\geometry\_triangulation_debugger.py:3:67: W291 trailing whitespace
# vispy\geometry\_triangulation_debugger.py:4:33: W291 trailing whitespace
# vispy\geometry\_triangulation_debugger.py:30:25: W291 trailing whitespace
# vispy\geometry\_triangulation_debugger.py:36:68: W291 trailing whitespace
# vispy\geometry\_triangulation_debugger.py:39:60: W291 trailing whitespace
# vispy\geometry\_triangulation_debugger.py:40:64: W291 trailing whitespace
# vispy\geometry\_triangulation_debugger.py:60:57: W291 trailing whitespace
# vispy\geometry\_triangulation_debugger.py:103:50: W291 trailing whitespace
# vispy\gloo\buffer.py:225:80: E501 line too long (81 > 79 characters)
# vispy\gloo\buffer.py:446:80: E501 line too long (95 > 79 characters)
# vispy\gloo\context.py:65:18: W291 trailing whitespace
# vispy\gloo\context.py:195:37: W291 trailing whitespace
# vispy\gloo\framebuffer.py:192:80: E501 line too long (80 > 79 characters)
# vispy\gloo\glir.py:155:80: E501 line too long (92 > 79 characters)
# vispy\gloo\glir.py:355:80: E501 line too long (103 > 79 characters)
# vispy\gloo\glir.py:461:80: E501 line too long (91 > 79 characters)
# vispy\gloo\glir.py:660:80: E501 line too long (91 > 79 characters)
# vispy\gloo\glir.py:826:80: E501 line too long (96 > 79 characters)
# vispy\gloo\glir.py:849:80: E501 line too long (86 > 79 characters)
# vispy\gloo\glir.py:1380:80: E501 line too long (82 > 79 characters)
# vispy\gloo\glir.py:1482:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\gloo\glir.py:1544:80: E501 line too long (88 > 79 characters)
# vispy\gloo\glir.py:1640:80: E501 line too long (88 > 79 characters)
# vispy\gloo\glir.py:1681:80: E501 line too long (88 > 79 characters)
# vispy\gloo\globject.py:33:1: W293 blank line contains whitespace
# vispy\gloo\globject.py:35:35: W291 trailing whitespace
# vispy\gloo\globject.py:45:80: E501 line too long (86 > 79 characters)
# vispy\gloo\globject.py:60:64: W291 trailing whitespace
# vispy\gloo\globject.py:76:38: W291 trailing whitespace
# vispy\gloo\globject.py:79:80: E501 line too long (114 > 79 characters)
# vispy\gloo\globject.py:95:80: E501 line too long (113 > 79 characters)
# vispy\gloo\program.py:116:33: W291 trailing whitespace
# vispy\gloo\program.py:160:80: E501 line too long (81 > 79 characters)
# vispy\gloo\texture.py:91:80: E501 line too long (80 > 79 characters)
# vispy\gloo\texture.py:258:80: E501 line too long (81 > 79 characters)
# vispy\gloo\texture.py:300:80: E501 line too long (85 > 79 characters)
# vispy\gloo\texture.py:461:80: E501 line too long (81 > 79 characters)
# vispy\gloo\texture.py:527:80: E501 line too long (81 > 79 characters)
# vispy\gloo\texture.py:599:80: E501 line too long (81 > 79 characters)
# vispy\gloo\texture.py:613:80: E501 line too long (81 > 79 characters)
# vispy\gloo\texture.py:654:80: E501 line too long (84 > 79 characters)
# vispy\gloo\texture.py:674:80: E501 line too long (81 > 79 characters)
# vispy\gloo\wrappers.py:618:80: E501 line too long (83 > 79 characters)
# vispy\gloo\wrappers.py:711:80: E501 line too long (80 > 79 characters)
# vispy\gloo\gl\es2.py:5:18: W291 trailing whitespace
# vispy\gloo\gl\es2.py:20:21: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:54:65: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:60:74: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:61:67: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:62:74: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:63:73: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:64:78: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:65:74: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:66:74: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:67:67: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:68:68: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:69:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:70:78: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:71:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:72:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:73:69: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:74:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:75:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:76:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:77:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:78:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:79:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:80:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:81:57: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:82:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:83:71: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:84:75: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:85:69: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:86:61: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:87:71: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:88:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:89:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:90:74: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:91:72: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:92:68: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:93:70: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:94:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:95:70: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:96:70: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:97:67: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:98:62: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:99:63: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:100:62: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:101:63: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:102:62: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:103:63: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:104:62: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:105:63: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:106:62: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:107:63: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:108:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:109:67: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:110:71: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:111:72: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:112:71: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:113:60: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:114:74: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:115:78: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:116:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:117:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:118:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:119:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:120:75: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:121:71: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:122:73: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:123:65: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:124:65: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:125:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:126:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:127:69: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:128:72: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:129:69: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:130:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:131:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:132:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:133:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:134:77: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:135:76: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:136:72: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:137:73: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:138:69: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:139:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:140:67: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:141:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:142:67: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:143:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:144:78: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:145:78: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:146:78: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:147:78: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:148:64: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:149:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:150:62: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:151:60: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:152:60: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:153:64: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:154:63: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:155:64: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:156:64: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:157:65: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:158:63: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:159:65: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:160:78: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:161:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:162:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:163:66: W291 trailing whitespace
# vispy\gloo\gl\glplus.py:164:51: W291 trailing whitespace
# vispy\gloo\gl\pyopengl2.py:37:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\gloo\gl\_constants.py:16:5: E301 expected 1 blank line, found 0
# vispy\gloo\gl\_constants.py:85:80: E501 line too long (80 > 79 characters)
# vispy\gloo\gl\_constants.py:101:80: E501 line too long (92 > 79 characters)
# vispy\gloo\gl\_constants.py:102:80: E501 line too long (92 > 79 characters)
# vispy\gloo\gl\_constants.py:103:80: E501 line too long (112 > 79 characters)
# vispy\gloo\gl\_constants.py:104:80: E501 line too long (96 > 79 characters)
# vispy\gloo\gl\_constants.py:107:80: E501 line too long (90 > 79 characters)
# vispy\gloo\gl\_constants.py:108:80: E501 line too long (90 > 79 characters)
# vispy\gloo\gl\_constants.py:109:80: E501 line too long (106 > 79 characters)
# vispy\gloo\gl\_constants.py:123:80: E501 line too long (88 > 79 characters)
# vispy\gloo\gl\_constants.py:124:80: E501 line too long (84 > 79 characters)
# vispy\gloo\gl\_constants.py:133:80: E501 line too long (81 > 79 characters)
# vispy\gloo\gl\_constants.py:152:80: E501 line too long (88 > 79 characters)
# vispy\gloo\gl\_constants.py:154:80: E501 line too long (80 > 79 characters)
# vispy\gloo\gl\_constants.py:160:80: E501 line too long (84 > 79 characters)
# vispy\gloo\gl\_constants.py:174:80: E501 line too long (84 > 79 characters)
# vispy\gloo\gl\_constants.py:197:80: E501 line too long (80 > 79 characters)
# vispy\gloo\gl\_constants.py:232:80: E501 line too long (80 > 79 characters)
# vispy\gloo\gl\_constants.py:233:80: E501 line too long (80 > 79 characters)
# vispy\gloo\gl\_constants.py:312:80: E501 line too long (92 > 79 characters)
# vispy\gloo\gl\_constants.py:314:80: E501 line too long (84 > 79 characters)
# vispy\gloo\gl\_es2.py:10:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:16:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:20:80: E501 line too long (83 > 79 characters)
# vispy\gloo\gl\_es2.py:22:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:24:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:29:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:35:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:41:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:47:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:51:80: E501 line too long (92 > 79 characters)
# vispy\gloo\gl\_es2.py:52:80: E501 line too long (82 > 79 characters)
# vispy\gloo\gl\_es2.py:53:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:59:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:65:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:71:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:75:80: E501 line too long (95 > 79 characters)
# vispy\gloo\gl\_es2.py:76:80: E501 line too long (92 > 79 characters)
# vispy\gloo\gl\_es2.py:77:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:81:80: E501 line too long (93 > 79 characters)
# vispy\gloo\gl\_es2.py:82:80: E501 line too long (81 > 79 characters)
# vispy\gloo\gl\_es2.py:83:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:95:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:98:80: E501 line too long (99 > 79 characters)
# vispy\gloo\gl\_es2.py:99:80: E501 line too long (87 > 79 characters)
# vispy\gloo\gl\_es2.py:100:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:106:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:112:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:118:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:122:80: E501 line too long (92 > 79 characters)
# vispy\gloo\gl\_es2.py:123:80: E501 line too long (82 > 79 characters)
# vispy\gloo\gl\_es2.py:124:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:130:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:136:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:140:80: E501 line too long (87 > 79 characters)
# vispy\gloo\gl\_es2.py:141:80: E501 line too long (85 > 79 characters)
# vispy\gloo\gl\_es2.py:142:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:148:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:152:80: E501 line too long (155 > 79 characters)
# vispy\gloo\gl\_es2.py:153:80: E501 line too long (160 > 79 characters)
# vispy\gloo\gl\_es2.py:154:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:154:80: E501 line too long (87 > 79 characters)
# vispy\gloo\gl\_es2.py:159:5: F841 local variable 'size' is assigned to but never used
# vispy\gloo\gl\_es2.py:161:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:161:80: E501 line too long (108 > 79 characters)
# vispy\gloo\gl\_es2.py:161:93: F821 undefined name 'imageSize'
# vispy\gloo\gl\_es2.py:164:80: E501 line too long (172 > 79 characters)
# vispy\gloo\gl\_es2.py:165:80: E501 line too long (171 > 79 characters)
# vispy\gloo\gl\_es2.py:166:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:166:80: E501 line too long (92 > 79 characters)
# vispy\gloo\gl\_es2.py:170:5: F841 local variable 'size' is assigned to but never used
# vispy\gloo\gl\_es2.py:172:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:172:80: E501 line too long (113 > 79 characters)
# vispy\gloo\gl\_es2.py:172:98: F821 undefined name 'imageSize'
# vispy\gloo\gl\_es2.py:175:80: E501 line too long (146 > 79 characters)
# vispy\gloo\gl\_es2.py:176:80: E501 line too long (139 > 79 characters)
# vispy\gloo\gl\_es2.py:177:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:177:80: E501 line too long (81 > 79 characters)
# vispy\gloo\gl\_es2.py:178:80: E501 line too long (85 > 79 characters)
# vispy\gloo\gl\_es2.py:181:80: E501 line too long (148 > 79 characters)
# vispy\gloo\gl\_es2.py:182:80: E501 line too long (135 > 79 characters)
# vispy\gloo\gl\_es2.py:183:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:184:80: E501 line too long (82 > 79 characters)
# vispy\gloo\gl\_es2.py:190:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:197:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:203:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:209:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:212:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:215:80: E501 line too long (81 > 79 characters)
# vispy\gloo\gl\_es2.py:217:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:220:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:225:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:229:80: E501 line too long (82 > 79 characters)
# vispy\gloo\gl\_es2.py:231:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:234:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:239:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:245:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:248:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:253:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:259:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:265:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:271:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:277:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:283:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:289:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:293:80: E501 line too long (91 > 79 characters)
# vispy\gloo\gl\_es2.py:294:80: E501 line too long (81 > 79 characters)
# vispy\gloo\gl\_es2.py:295:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:305:9: F841 local variable 'offset_' is assigned to but never used
# vispy\gloo\gl\_es2.py:308:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:313:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:319:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:325:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:331:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:335:80: E501 line too long (101 > 79 characters)
# vispy\gloo\gl\_es2.py:336:80: E501 line too long (116 > 79 characters)
# vispy\gloo\gl\_es2.py:337:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:337:80: E501 line too long (84 > 79 characters)
# vispy\gloo\gl\_es2.py:338:80: E501 line too long (88 > 79 characters)
# vispy\gloo\gl\_es2.py:341:80: E501 line too long (112 > 79 characters)
# vispy\gloo\gl\_es2.py:342:80: E501 line too long (112 > 79 characters)
# vispy\gloo\gl\_es2.py:343:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:349:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:355:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:358:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:364:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:367:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:373:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:376:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:382:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:385:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:391:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:395:80: E501 line too long (185 > 79 characters)
# vispy\gloo\gl\_es2.py:396:80: E501 line too long (131 > 79 characters)
# vispy\gloo\gl\_es2.py:397:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:403:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:403:80: E501 line too long (83 > 79 characters)
# vispy\gloo\gl\_es2.py:408:80: E501 line too long (186 > 79 characters)
# vispy\gloo\gl\_es2.py:409:80: E501 line too long (132 > 79 characters)
# vispy\gloo\gl\_es2.py:410:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:416:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:416:80: E501 line too long (84 > 79 characters)
# vispy\gloo\gl\_es2.py:421:80: E501 line too long (126 > 79 characters)
# vispy\gloo\gl\_es2.py:422:80: E501 line too long (96 > 79 characters)
# vispy\gloo\gl\_es2.py:423:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:427:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:434:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:442:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:444:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:448:80: E501 line too long (98 > 79 characters)
# vispy\gloo\gl\_es2.py:450:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:453:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:460:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:466:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:470:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:471:37: E225 missing whitespace around operator
# vispy\gloo\gl\_es2.py:478:80: E501 line too long (128 > 79 characters)
# vispy\gloo\gl\_es2.py:479:80: E501 line too long (109 > 79 characters)
# vispy\gloo\gl\_es2.py:480:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:483:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:483:80: E501 line too long (87 > 79 characters)
# vispy\gloo\gl\_es2.py:489:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:493:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:494:37: E225 missing whitespace around operator
# vispy\gloo\gl\_es2.py:501:80: E501 line too long (111 > 79 characters)
# vispy\gloo\gl\_es2.py:502:80: E501 line too long (95 > 79 characters)
# vispy\gloo\gl\_es2.py:503:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:507:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:511:80: E501 line too long (90 > 79 characters)
# vispy\gloo\gl\_es2.py:513:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:515:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:519:80: E501 line too long (104 > 79 characters)
# vispy\gloo\gl\_es2.py:520:80: E501 line too long (81 > 79 characters)
# vispy\gloo\gl\_es2.py:521:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:524:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:528:80: E501 line too long (110 > 79 characters)
# vispy\gloo\gl\_es2.py:529:80: E501 line too long (93 > 79 characters)
# vispy\gloo\gl\_es2.py:530:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:534:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:538:80: E501 line too long (132 > 79 characters)
# vispy\gloo\gl\_es2.py:539:80: E501 line too long (108 > 79 characters)
# vispy\gloo\gl\_es2.py:540:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:543:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:543:80: E501 line too long (86 > 79 characters)
# vispy\gloo\gl\_es2.py:547:80: E501 line too long (109 > 79 characters)
# vispy\gloo\gl\_es2.py:548:80: E501 line too long (91 > 79 characters)
# vispy\gloo\gl\_es2.py:549:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:553:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:557:80: E501 line too long (89 > 79 characters)
# vispy\gloo\gl\_es2.py:559:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:561:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:568:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:587:80: E501 line too long (97 > 79 characters)
# vispy\gloo\gl\_es2.py:589:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:592:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:596:80: E501 line too long (91 > 79 characters)
# vispy\gloo\gl\_es2.py:598:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:602:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:603:37: E225 missing whitespace around operator
# vispy\gloo\gl\_es2.py:613:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:619:80: E501 line too long (97 > 79 characters)
# vispy\gloo\gl\_es2.py:621:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:625:5: F841 local variable 'res' is assigned to but never used
# vispy\gloo\gl\_es2.py:626:37: E225 missing whitespace around operator
# vispy\gloo\gl\_es2.py:633:80: E501 line too long (104 > 79 characters)
# vispy\gloo\gl\_es2.py:634:80: E501 line too long (80 > 79 characters)
# vispy\gloo\gl\_es2.py:635:1: E302 expected 2 blank lines, found 0
# vispy\gloo\gl\_es2.py:637:5: F841 local variable 'res' is assigned to but never used
# ...
# vispy\visuals\volume.py:790:80: E501 line too long (88 > 79 characters)
# vispy\visuals\volume.py:791:80: E501 line too long (88 > 79 characters)
# vispy\visuals\volume.py:852:80: E501 line too long (91 > 79 characters)
# vispy\visuals\volume.py:861:80: E501 line too long (81 > 79 characters)
# vispy\visuals\volume.py:863:80: E501 line too long (91 > 79 characters)
# vispy\visuals\volume.py:864:80: E501 line too long (108 > 79 characters)
# vispy\visuals\volume.py:865:80: E501 line too long (82 > 79 characters)
# vispy\visuals\volume.py:875:80: E501 line too long (102 > 79 characters)
# vispy\visuals\volume.py:877:80: E501 line too long (115 > 79 characters)
# vispy\visuals\volume.py:878:80: E501 line too long (91 > 79 characters)
# vispy\visuals\volume.py:909:80: E501 line too long (98 > 79 characters)
# vispy\visuals\volume.py:959:80: E501 line too long (87 > 79 characters)
# vispy\visuals\volume.py:962:80: E501 line too long (85 > 79 characters)
# vispy\visuals\volume.py:966:80: E501 line too long (82 > 79 characters)
# vispy\visuals\volume.py:990:80: E501 line too long (99 > 79 characters)
# vispy\visuals\volume.py:992:80: E501 line too long (85 > 79 characters)
# vispy\visuals\volume.py:1008:80: E501 line too long (81 > 79 characters)
# vispy\visuals\volume.py:1040:80: E501 line too long (80 > 79 characters)
# vispy\visuals\volume.py:1050:80: E501 line too long (84 > 79 characters)
# vispy\visuals\volume.py:1069:80: E501 line too long (82 > 79 characters)
# vispy\visuals\volume.py:1156:80: E501 line too long (94 > 79 characters)
# vispy\visuals\windbarb.py:61:80: E501 line too long (87 > 79 characters)
# vispy\visuals\windbarb.py:92:1: W293 blank line contains whitespace
# vispy\visuals\windbarb.py:94:1: W293 blank line contains whitespace
# vispy\visuals\windbarb.py:101:1: W293 blank line contains whitespace
# vispy\visuals\windbarb.py:104:1: W293 blank line contains whitespace
# vispy\visuals\windbarb.py:144:80: E501 line too long (82 > 79 characters)
# vispy\visuals\windbarb.py:196:80: E501 line too long (93 > 79 characters)
# vispy\visuals\_scalable_textures.py:27:80: E501 line too long (84 > 79 characters)
# vispy\visuals\_scalable_textures.py:71:80: E501 line too long (80 > 79 characters)
# vispy\visuals\_scalable_textures.py:75:80: E501 line too long (85 > 79 characters)
# vispy\visuals\_scalable_textures.py:145:80: E501 line too long (82 > 79 characters)
# vispy\visuals\_scalable_textures.py:302:80: E501 line too long (86 > 79 characters)
# vispy\visuals\_scalable_textures.py:363:80: E501 line too long (84 > 79 characters)
# vispy\visuals\_scalable_textures.py:369:80: E501 line too long (83 > 79 characters)
# vispy\visuals\_scalable_textures.py:371:80: E501 line too long (80 > 79 characters)
# vispy\visuals\_scalable_textures.py:392:80: E501 line too long (107 > 79 characters)
# vispy\visuals\_scalable_textures.py:401:80: E501 line too long (90 > 79 characters)
# vispy\visuals\_scalable_textures.py:425:80: E501 line too long (84 > 79 characters)
# vispy\visuals\_scalable_textures.py:435:80: E501 line too long (86 > 79 characters)
# vispy\visuals\collections\agg_segment_collection.py:76:35: W291 trailing whitespace
# vispy\visuals\collections\collection.py:62:75: W291 trailing whitespace
# vispy\visuals\collections\collection.py:91:80: E501 line too long (95 > 79 characters)
# vispy\visuals\collections\collection.py:92:80: E501 line too long (89 > 79 characters)
# vispy\visuals\collections\collection.py:96:80: E501 line too long (95 > 79 characters)
# vispy\visuals\collections\collection.py:97:80: E501 line too long (89 > 79 characters)
# vispy\visuals\collections\collection.py:104:64: W291 trailing whitespace
# vispy\visuals\collections\raw_path_collection.py:55:35: W291 trailing whitespace
# vispy\visuals\collections\raw_point_collection.py:64:35: W291 trailing whitespace
# vispy\visuals\collections\raw_polygon_collection.py:29:35: W291 trailing whitespace
# vispy\visuals\collections\raw_segment_collection.py:60:35: W291 trailing whitespace
# vispy\visuals\collections\raw_triangle_collection.py:31:35: W291 trailing whitespace
# vispy\visuals\collections\util.py:83:80: E501 line too long (80 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:19:80: E501 line too long (114 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:21:80: E501 line too long (98 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:34:80: E501 line too long (83 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:43:80: E501 line too long (95 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:60:80: E501 line too long (98 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:67:80: E501 line too long (87 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:72:80: E501 line too long (91 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:80:80: E501 line too long (81 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:83:80: E501 line too long (94 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:84:80: E501 line too long (82 > 79 characters)
# vispy\visuals\filters\clipping_planes.py:95:80: E501 line too long (114 > 79 characters)
# vispy\visuals\filters\color.py:63:80: E501 line too long (84 > 79 characters)
# vispy\visuals\filters\color.py:140:80: E501 line too long (86 > 79 characters)
# vispy\visuals\filters\color.py:168:80: E501 line too long (80 > 79 characters)
# vispy\visuals\filters\color.py:169:80: E501 line too long (90 > 79 characters)
# vispy\visuals\filters\mesh.py:147:80: E501 line too long (83 > 79 characters)
# vispy\visuals\filters\mesh.py:247:80: E501 line too long (95 > 79 characters)
# vispy\visuals\filters\tests\test_wireframe_filter.py:1:24: W291 trailing whitespace
# vispy\visuals\filters\tests\__init__.py:1:24: W291 trailing whitespace
# vispy\visuals\glsl\color.py:21:80: E501 line too long (84 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:3:80: E501 line too long (95 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:15:80: E501 line too long (118 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:21:80: E501 line too long (97 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:22:80: E501 line too long (118 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:23:80: E501 line too long (93 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:25:80: E501 line too long (106 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:28:80: E501 line too long (94 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:44:80: E501 line too long (81 > 79 characters)
# vispy\visuals\graphs\layouts\networkx_layout.py:86:80: E501 line too long (107 > 79 characters)
# vispy\visuals\graphs\tests\test_networkx_layout.py:23:80: E501 line too long (90 > 79 characters)
# vispy\visuals\line\arrow.py:112:74: W291 trailing whitespace
# vispy\visuals\line\line.py:298:80: E501 line too long (93 > 79 characters)
# vispy\visuals\line\line.py:334:80: E501 line too long (81 > 79 characters)
# vispy\visuals\line\line.py:419:80: E501 line too long (93 > 79 characters)
# vispy\visuals\shaders\compiler.py:42:80: E501 line too long (83 > 79 characters)
# vispy\visuals\shaders\function.py:345:80: E501 line too long (82 > 79 characters)
# vispy\visuals\shaders\function.py:401:80: E501 line too long (85 > 79 characters)
# vispy\visuals\shaders\function.py:414:80: E501 line too long (80 > 79 characters)
# vispy\visuals\shaders\function.py:479:80: E501 line too long (86 > 79 characters)
# vispy\visuals\shaders\function.py:521:80: E501 line too long (80 > 79 characters)
# vispy\visuals\shaders\multiprogram.py:8:20: W291 trailing whitespace
# vispy\visuals\shaders\multiprogram.py:32:78: W291 trailing whitespace
# vispy\visuals\shaders\multiprogram.py:35:75: W291 trailing whitespace
# vispy\visuals\shaders\multiprogram.py:59:80: E501 line too long (81 > 79 characters)
# vispy\visuals\shaders\multiprogram.py:70:80: E501 line too long (83 > 79 characters)
# vispy\visuals\shaders\multiprogram.py:81:80: E501 line too long (83 > 79 characters)
# vispy\visuals\shaders\multiprogram.py:126:60: W291 trailing whitespace
# vispy\visuals\shaders\multiprogram.py:143:80: E501 line too long (84 > 79 characters)
# vispy\visuals\shaders\program.py:89:78: W291 trailing whitespace
# vispy\visuals\shaders\program.py:96:48: W291 trailing whitespace
# vispy\visuals\shaders\program.py:134:77: W291 trailing whitespace
# vispy\visuals\shaders\program.py:159:69: W291 trailing whitespace
# vispy\visuals\shaders\shader_object.py:66:80: E501 line too long (80 > 79 characters)
# vispy\visuals\shaders\variable.py:165:80: E501 line too long (86 > 79 characters)
# vispy\visuals\shaders\tests\test_function.py:35:2: W291 trailing whitespace
# vispy\visuals\shaders\tests\test_function.py:258:54: W291 trailing whitespace
# vispy\visuals\shaders\tests\test_function.py:447:1: W293 blank line contains whitespace
# vispy\visuals\shaders\tests\test_function.py:451:1: W293 blank line contains whitespace
# vispy\visuals\shaders\tests\test_multiprogram.py:11:1: W293 blank line contains whitespace
# vispy\visuals\tests\test_arrows.py:10:80: E501 line too long (84 > 79 characters)
# vispy\visuals\tests\test_axis.py:29:80: E501 line too long (89 > 79 characters)
# vispy\visuals\tests\test_axis.py:42:80: E501 line too long (80 > 79 characters)
# vispy\visuals\tests\test_axis.py:47:80: E501 line too long (87 > 79 characters)
# vispy\visuals\tests\test_axis.py:77:71: W291 trailing whitespace
# vispy\visuals\tests\test_axis.py:78:67: W291 trailing whitespace
# vispy\visuals\tests\test_axis.py:102:80: E501 line too long (89 > 79 characters)
# vispy\visuals\tests\test_axis.py:110:80: E501 line too long (109 > 79 characters)
# vispy\visuals\tests\test_axis.py:118:80: E501 line too long (109 > 79 characters)
# vispy\visuals\tests\test_axis.py:120:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\visuals\tests\test_ellipse.py:11:64: W291 trailing whitespace
# vispy\visuals\tests\test_image.py:40:80: E501 line too long (82 > 79 characters)
# vispy\visuals\tests\test_image.py:75:80: E501 line too long (86 > 79 characters)
# vispy\visuals\tests\test_image.py:86:80: E501 line too long (82 > 79 characters)
# vispy\visuals\tests\test_image.py:113:80: E501 line too long (81 > 79 characters)
# vispy\visuals\tests\test_image.py:118:80: E501 line too long (83 > 79 characters)
# vispy\visuals\tests\test_image.py:119:80: E501 line too long (107 > 79 characters)
# vispy\visuals\tests\test_image.py:124:80: E501 line too long (83 > 79 characters)
# vispy\visuals\tests\test_mesh_normals.py:186:80: E501 line too long (80 > 79 characters)
# vispy\visuals\tests\test_sdf.py:55:80: E501 line too long (80 > 79 characters)
# vispy\visuals\tests\test_sdf.py:69:80: E501 line too long (104 > 79 characters)
# vispy\visuals\tests\test_spectrogram.py:42:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\visuals\tests\test_text.py:67:80: E501 line too long (86 > 79 characters)
# vispy\visuals\tests\test_volume.py:83:80: E501 line too long (86 > 79 characters)
# vispy\visuals\tests\test_volume.py:90:80: E501 line too long (86 > 79 characters)
# vispy\visuals\tests\test_volume.py:129:80: E501 line too long (81 > 79 characters)
# vispy\visuals\tests\test_volume.py:135:80: E501 line too long (83 > 79 characters)
# vispy\visuals\tests\test_volume.py:136:80: E501 line too long (107 > 79 characters)
# vispy\visuals\tests\test_volume.py:142:80: E501 line too long (83 > 79 characters)
# vispy\visuals\tests\test_volume.py:149:80: E501 line too long (87 > 79 characters)
# vispy\visuals\tests\test_windbarb.py:33:1: E305 expected 2 blank lines after class or function definition, found 1
# vispy\visuals\text\text.py:165:80: E501 line too long (80 > 79 characters)
# vispy\visuals\text\text.py:409:80: E501 line too long (93 > 79 characters)
# vispy\visuals\text\text.py:637:80: E501 line too long (86 > 79 characters)
# vispy\visuals\transforms\base_transform.py:107:69: W291 trailing whitespace
# vispy\visuals\transforms\base_transform.py:110:72: W291 trailing whitespace
# vispy\visuals\transforms\base_transform.py:135:28: W291 trailing whitespace
# vispy\visuals\transforms\base_transform.py:169:66: W291 trailing whitespace
# vispy\visuals\transforms\chain.py:56:77: W291 trailing whitespace
# vispy\visuals\transforms\chain.py:57:73: W291 trailing whitespace
# vispy\visuals\transforms\chain.py:58:19: W291 trailing whitespace
# vispy\visuals\transforms\chain.py:291:62: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:168:30: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:171:22: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:189:71: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:190:69: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:191:68: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:193:78: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:195:72: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:207:1: W293 blank line contains whitespace
# vispy\visuals\transforms\nonlinear.py:212:1: W293 blank line contains whitespace
# vispy\visuals\transforms\nonlinear.py:217:1: W293 blank line contains whitespace
# vispy\visuals\transforms\nonlinear.py:237:80: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:271:80: E501 line too long (84 > 79 characters)
# vispy\visuals\transforms\nonlinear.py:325:34: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:373:70: W291 trailing whitespace
# vispy\visuals\transforms\nonlinear.py:384:1: W293 blank line contains whitespace
# vispy\visuals\transforms\transform_system.py:25:73: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:37:78: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:42:77: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:43:74: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:47:74: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:51:71: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:157:66: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:180:78: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:181:71: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:184:71: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:200:72: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:236:38: W291 trailing whitespace
# vispy\visuals\transforms\transform_system.py:253:80: E501 line too long (84 > 79 characters)
# vispy\visuals\transforms\transform_system.py:269:80: E501 line too long (93 > 79 characters)
# vispy\visuals\transforms\transform_system.py:278:80: E501 line too long (89 > 79 characters)
# vispy\visuals\transforms\transform_system.py:287:80: E501 line too long (116 > 79 characters)
# vispy\visuals\transforms\transform_system.py:296:80: E501 line too long (93 > 79 characters)
# vispy\visuals\transforms\transform_system.py:305:80: E501 line too long (90 > 79 characters)
# Failed: flake8 failed
# Testing failed (['pyqt5', 'nobackend', 'flake'] failed, ['pyqt4', 'pyqt6', 'pyside', 'pyside2', 'pyside6', 'pyglet', 'glfw', 'sdl2', 'wx', 'egl', 'osmesa', 'jupyter_rfb', '_test', 'examples'] skipped) in 38.230 seconds
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-c4ed51ced46e> in <module>
#       1 import vispy
#       2
# ----> 3 vispy.test()
#
# ~\anaconda3\lib\site-packages\vispy\util\wrappers.py in test(*args, **kwargs)
#     151     """Proxy function to delay `.testing` import"""
#     152     from vispy.testing import test as _test  # noqa
# --> 153     return _test(*args, **kwargs)
#     154
#     155 test.__test__ = False  # no discover test function as test
#
# ~\anaconda3\lib\site-packages\vispy\testing\_runners.py in test(label, extra_arg_string, coverage)
#     450     sys.stdout.flush()
#     451     if len(fail) > 0:
# --> 452         raise RuntimeError('FAILURE')
#
# RuntimeError: FAILURE

# %%
import matplotlib
matplotlib.use("Qt5Agg")

from visbrain.gui import Brain

Brain().show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-505b5a541064> in <module>
#       2 matplotlib.use("Qt5Agg")
#       3
# ----> 4 from visbrain.gui import Brain
#       5
#       6 Brain().show()
#
# ~\AppData\Roaming\Python\Python38\site-packages\visbrain\gui\__init__.py in <module>
# ----> 1 from .brain import Brain  # noqa
#       2 from .figure import Figure  # noqa
#       3 from .signal import Signal  # noqa
#       4 from .sleep import Sleep  # noqa
#
# ~\AppData\Roaming\Python\Python38\site-packages\visbrain\gui\brain\__init__.py in <module>
#       1 """From the brain file, import the brain module."""
# ----> 2 from .brain import Brain
#
# ~\AppData\Roaming\Python\Python38\site-packages\visbrain\gui\brain\brain.py in <module>
#      11 import vispy.scene.cameras as viscam
#      12
# ---> 13 from .interface import UiInit, UiElements, BrainShortcuts
#      14 from .visuals import Visuals
#      15 from .cbar import BrainCbar
#
# ~\AppData\Roaming\Python\Python38\site-packages\visbrain\gui\brain\interface\__init__.py in <module>
#       1 """Import uiElements and uiInit."""
# ----> 2 from .ui_init import UiInit, BrainShortcuts
#       3 from .ui_elements import UiElements
#
# ~\AppData\Roaming\Python\Python38\site-packages\visbrain\gui\brain\interface\ui_init.py in <module>
#       7 """
#       8
# ----> 9 from PyQt5 import QtWidgets
#      10
#      11 from vispy import app
#
# ImportError: DLL load failed while importing QtWidgets: The specified procedure could not be found.

# %%
from __future__ import print_function
import numpy as np

from visbrain.gui import Brain
from visbrain.objects import BrainObj, SourceObj, RoiObj
from visbrain.io import download_file

"""Download the location of sources closed to the thalamus and the power of
alpha oscillations
"""
thalamus_xyz = download_file('thalamus.txt', astype='example_data')
thalamus_data = download_file('Px.npy', astype='example_data')
s_xyz = np.loadtxt(thalamus_xyz)
s_data = np.load(thalamus_data).mean(1)

"""Create a source object
"""
s_obj = SourceObj('ThalamusSources', s_xyz, data=s_data, color='#ab4642',
                  radius_min=10., radius_max=20.)

"""Create a ROI object. The ROI object comes with three default templates :
* 'brodmann' : Brodmann areas
* 'aal' : Automatic Anatomical Labeling
* 'talairach'

You can also define your own RoiObj with your own labels.
"""
roi_obj = RoiObj('aal', cblabel="Alpha power", border=False)

"""Find index of the thalamus and get the mesh.

If you want to get all of the index of the ROI template use :
* `roi_obj.get_labels()` : return a pandas DatFrame
* `roi_obj.get_labels('/home/')` : save all supported ROI and labels in an
  excel file.
"""
idx_thalamus = roi_obj.where_is('Thalamus')
roi_obj.select_roi(idx_thalamus, smooth=5)

"""Once the ROI object created, we can project source's alpha modulations
directly on the thalamus
"""
roi_obj.project_sources(s_obj, cmap='Spectral_r', clim=(200., 2000.),
                        vmin=300., under='gray', vmax=1800., over='darkred')

"""You can also force sources to fit onto the thalamus
"""
# s_obj.fit_to_vertices(roi_obj.vertices)

"""
"""
b_obj = BrainObj('B3')

# Define a Brain instance :
vb = Brain(brain_obj=b_obj, source_obj=s_obj, roi_obj=roi_obj)

"""Select the colorbar of the ROI
"""
vb.cbar_select('roi')

"""Eventualy, take a screenshot
"""
# vb.screenshot('thalamus.png', autocrop=True)

# Show the interface :
vb.show()
